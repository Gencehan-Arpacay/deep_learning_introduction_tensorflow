# %% [markdown]
# # Neural network regression models

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.9.2

# %% [markdown]
# ## Creating some data to view and fit

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create the features

X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

plt.scatter(X,y);

# %% [markdown]
# ## Steps with modeling with tensorflow
#
# 1. Creating a model- Define the input and the output layers including the hidden layers of deep learning model
#
# 2. Compling a model - define the loss function in other words tell the model who wrong it is and the optimizer tells the model how to improve the model and evaluation matrix
#
# 3. Fitting a model - letting the model try to find patterns between x and y

# %%
# Turn np arrays to tensors

X = tf.cast(tf.constant(X), dtype = tf.float32)

y = tf.cast(tf.constant(y), dtype = tf.float32)


X, y
# Out:
# (<tf.Tensor: shape=(8,), dtype=float32, numpy=array([-7., -4., -1.,  2.,  5.,  8., 11., 14.], dtype=float32)>,
#  <tf.Tensor: shape=(8,), dtype=float32, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24.], dtype=float32)>)

# %%
y == X + 10
# Out:
# <tf.Tensor: shape=(8,), dtype=bool, numpy=array([ True,  True,  True,  True,  True,  True,  True,  True])>

# %%
inp_shape = X[0].shape
out_shape = y[0].shape

inp_shape, out_shape
# Out:
# (TensorShape([]), TensorShape([]))

# %%
# set random seed
tf.random.set_seed(42)

# 1. Creating a model using sequantial API

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), # this has resolved the issue of the dimensions error https://stackoverflow.com/questions/72423651/valueerror-for-sequential-model-fit
  tf.keras.layers.Dense(1)
])


# 2. Compile the model

model.compile(loss=tf.keras.losses.mae, #mea stands for mean absolute error
              optimizer = tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model
model.fit(X, y, epochs = 5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 292ms/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 11ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 8ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 8ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 9ms/step - loss: 10.9748 - mae: 10.9748

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# array([[12.716021]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# 1. Creating a model using sequantial API

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), # this has resolved the issue of the dimensions error https://stackoverflow.com/questions/72423651/valueerror-for-sequential-model-fit
  tf.keras.layers.Dense(1)
])


# 2. Compile the model

model.compile(loss=tf.keras.losses.mae, #mea stands for mean absolute error
              optimizer = tf.keras.optimizers.SGD(),
              metrics=["mae"])

# 3. Fit the model
model.fit(X, y, epochs = 150)
# Out:
# Epoch 1/150
# 1/1 [==============================] - 0s 307ms/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/150
# 1/1 [==============================] - 0s 13ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/150
# 1/1 [==============================] - 0s 12ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/150
# 1/1 [==============================] - 0s 10ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/150
# 1/1 [==============================] - 0s 10ms/step - loss: 10.9748 - mae: 10.9748
# Epoch 6/150
# 1/1 [==============================] - 0s 8ms/step - loss: 10.8423 - mae: 10.8423
# Epoch 7/150
# 1/1 [==============================] - 0s 21ms/step - loss: 10.7098 - mae: 10.7098
# Epoch 8/150
# 1/1 [==============================] - 0s 6ms/step - loss: 10.5773 - mae: 10.5773
# Epoch 9/150
# 1/1 [==============================] - 0s 9ms/step - loss: 10.4448 - mae: 10.4448
# Epoch 10/150
# 1/1 [==============================] - 0s 7ms/step - loss: 10.3123 - mae: 10.3123
# ...

# %%
model.predict([17.0])
# Out:
# 1/1 [==============================] - 0s 198ms/step
# array([[30.533512]], dtype=float32)

# %%
# set random seed
tf.random.set_seed(42)

# 1. Creating a model using sequantial API

model = tf.keras.Sequential([
    tf.keras.Input(shape=(1,)), # this has resolved the issue of the dimensions error https://stackoverflow.com/questions/72423651/valueerror-for-sequential-model-fit

  tf.keras.layers.Dense(1)
])


# 2. Compile the model

model.compile(loss=tf.keras.losses.mae, #mea stands for mean absolute error
              optimizer = tf.keras.optimizers.Adam(lr=0.1),
              metrics=["mae"])

# 3. Fit the model
model.fit(X, y, epochs = 800)
# Out:
# Epoch 1/800
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 0s 410ms/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/800
# 1/1 [==============================] - 0s 8ms/step - loss: 11.0548 - mae: 11.0548
# Epoch 3/800
# 1/1 [==============================] - 0s 10ms/step - loss: 10.6048 - mae: 10.6048
# Epoch 4/800
# 1/1 [==============================] - 0s 8ms/step - loss: 10.1548 - mae: 10.1548
# Epoch 5/800
# 1/1 [==============================] - 0s 8ms/step - loss: 9.7048 - mae: 9.7048
# Epoch 6/800
# 1/1 [==============================] - 0s 10ms/step - loss: 9.2548 - mae: 9.2548
# Epoch 7/800
# 1/1 [==============================] - 0s 12ms/step - loss: 8.8048 - mae: 8.8048
# Epoch 8/800
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3548 - mae: 8.3548
# ...

# %%
model.predict([78.0])
# Out:
# 1/1 [==============================] - 0s 183ms/step
# array([[87.284744]], dtype=float32)

# %%
X = tf.range(-100, 100, 4)

X
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96], dtype=int32)>

# %%
y = X + 10 
y
# Out:
# <tf.Tensor: shape=(50,), dtype=int32, numpy=
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %%
plt.plot(X, y)

# %%
X_train = X[:40]
y_train = y[:40]

X_test = X[40:]
y_test = y[40:]

len(X_train), len(X_test)
# Out:
# (40, 10)

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(30, input_shape=[1], name="input_layer"),
    tf.keras.layers.Dense(1, name="output_layer")
])

model.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.1),
              metrics=["mae"],
              )

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (Dense)         (None, 30)                60
#
#  output_layer (Dense)        (None, 1)                 31
#
# ...
# Total params: 91
# Trainable params: 91
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs = 100, verbose = 0)

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_layer (Dense)         (None, 30)                60
#
#  output_layer (Dense)        (None, 1)                 31
#
# ...
# Total params: 91
# Trainable params: 91
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Total params - totla number of parameters in the model
#
# * Trainable params are the paraments in the training
#
# * Non-trainable parameters - are not updated during traning this is typical when you bring in alread learned patterns or params from other models during *** transfer learning ***

# %%
model.predict([-100])
# Out:
# 1/1 [==============================] - 0s 59ms/step
# array([[-89.51867]], dtype=float32)

# %%
from tensorflow.keras.utils import plot_model

plot_model(model=model, show_shapes=True) #plot model will be important to check the number of hidden layers and the structure of the model

# %% [markdown]
# ### visualissing the models predictions
#
#
# to visualize the prediction test and real data shell be seen

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# 1/1 [==============================] - 0s 53ms/step
# array([[ 69.13149 ],
#        [ 73.097755],
#        [ 77.06402 ],
#        [ 81.03027 ],
#        [ 84.996506],
#        [ 88.962776],
#        [ 92.92903 ],
#        [ 96.89528 ],
#        [100.86153 ],
#        [104.82779 ]], dtype=float32)

# %%
y_test
# Out:
# <tf.Tensor: shape=(10,), dtype=int32, numpy=array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106], dtype=int32)>

# %% [markdown]
# 🔐 : If something is going to be used in the future you have to covert that into function

# %%
# Lets create a plotting function

def plot_predictions(train_data=X_train, train_labels=y_train, test_data = X_test, test_labels = y_test, predictions=y_pred):
  """
  Plots training and test data and compers predictions with real results
  """
  plt.figure(figsize=(10,7))
  plt.scatter(train_data, train_labels, c="b", label="Training data")
  plt.scatter(test_data, test_labels, c="g", label="Testing data")
  plt.scatter(test_data, predictions, c="r", label="Predictions")
  plt.legend()

# %%
plot_predictions(train_data=X_train,
                 train_labels=y_train,
                 test_data = X_test,
                 test_labels = y_test,
                 predictions=y_pred)

# %% [markdown]
# ### Evaluating our model's predictions with regression evaluation metrics
#
#
# depending on the problem we are working on there are different evaluation metrics since we are working on regression problems two main metrics:
# * MAE - mean absolute error, "on avg how wrong each models pred"
# > * ${MAE} = (\sum \limits _{i=1} ^{n}  y_{i}x_{i}) / n $
# > * tf.keras.losses.MAE
# > * It is a greate metric for any regression problem
# * MSE mean squared error
# > * ${MSE} = 1/n \sum \limits _{i=1} ^{n}  (Y_{i} - \hat{Y_{i}})^2 $
# > * Hat y is the y predictions
# > * tf.keras.losses.MSE
# > * We use this when larger errors are more significant
# * Huber:
# > * tf.keras.Huber()
# > * Combination of MSE and MAE less sensitive to outliers than MSE

# %%
# Evaluate the model on the test:

model.evaluate(X_test, y_test)
# Out:
# 1/1 [==============================] - 0s 128ms/step - loss: 1.0204 - mae: 1.0204
# [1.0203536748886108, 1.0203536748886108]

# %%
# Calculate the MSE, MAE
mae = tf.metrics.mean_absolute_error(y_test, tf.squeeze(y_pred))
mse = tf.metrics.mean_squared_error(y_test, tf.squeeze(y_pred))
print("MAE:", mae, 
      "MSE:", mse)
# Out:
# MAE: tf.Tensor(1.0203552, shape=(), dtype=float32) MSE: tf.Tensor(1.0505197, shape=(), dtype=float32)

# %%
def mae(y_true, y_pred):
  return tf.metrics.mean_absolute_error(y_true = y_true, y_pred=tf.squeeze(y_pred))
